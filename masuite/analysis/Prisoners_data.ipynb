# %% [markdown]
# # Iterated Prisoner's Dilemma Data

# %%
import numpy as np
import seaborn as sns
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from collections import Counter

import chart_studio.plotly as py
import plotly.figure_factory as ff

# %matplotlib inline

sns.set()

# %% [markdown]
# ### Extract Data Function

# %%
# Get DataFrame from csv file
def df_data(num):
    fname = 'Axl' + str(num) + '.csv'
    file_name = "C:/Users/drago/OneDrive - UW/Ratliff Research/prisoners_data/"+ fname
    simple_data = pd.read_csv(file_name)
    return simple_data

# %%
# View dataframe
data = df_data(1)
data
# Out:
#      Rank                               Name  Median_score  \
# 0       0                            ZD-Mem2      2.259863
# 1       1                 CollectiveStrategy      2.258154
# 2       2                  Arrogant QLearner      2.258038
# 3       3                  Second by Getzler      2.256603
# 4       4                           Prober 2      2.256403
# ..    ...                                ...           ...
# 233   233                       Resurrection      2.243259
# 234   234             Suspicious Tit For Tat      2.242753
# 235   235      Knowledgeable Worse and Worse      2.242700
# 236   236                Nice Average Copier      2.242352
# 237   237  Meta Hunter Aggressive: 7 players      2.241930
#
#      Cooperation_rating   Wins  Initial_C_rate   CC_rate   CD_rate   DC_rate  \
# 0              0.499120  118.0        0.500422  0.250359  0.248762  0.251323
# 1              0.499498  118.0        0.513502  0.250848  0.248650  0.251306
# ...

# %% [markdown]
# ### Plotting Function

# %%
# Given parameters plot graph
def data_plot(fig, ax, x, y, xlabeler, ylabeler, conv_label=False, figsize=[9, 4]):
    
    # Plot
    fig.set_size_inches(figsize)
    ax.plot(x, y, 'go')
    
    # Plot Trendline
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.plot(x, p(x),"r--")

    ax.set_xlabel(xlabeler)
    ax.set_ylabel(ylabeler)
    ax.set_title(xlabeler + ' vs ' + ylabeler + ' in IPD')

    return 0

# %% [markdown]
# ### Graphs

# %%
# Plot data
figure
plt.ylabel("Cooperation Rating")
plt.xlabel("Median Score")
plt.xlim([2.1, 2.4])
plt.ylim([0, 1])
plt.title("Cooperating Rating vs Median Score in IPD")
plt.plot(data.Median_score, data.Cooperation_rating, 'go')

# Plot trendline
z = np.polyfit(data.Median_score, data.Cooperation_rating, 1)
p = np.poly1d(z)
plt.plot(data.Median_score,p(data.Median_score),"r--")

# %%
# Plot all data

#data_plot(fig, ax, )
# Out:
#      Rank                               Name  Median_score  \
# 0       0                            ZD-Mem2      2.259863
# 1       1                 CollectiveStrategy      2.258154
# 2       2                  Arrogant QLearner      2.258038
# 3       3                  Second by Getzler      2.256603
# 4       4                           Prober 2      2.256403
# ..    ...                                ...           ...
# 233   233                       Resurrection      2.243259
# 234   234             Suspicious Tit For Tat      2.242753
# 235   235      Knowledgeable Worse and Worse      2.242700
# 236   236                Nice Average Copier      2.242352
# 237   237  Meta Hunter Aggressive: 7 players      2.241930
#
#      Cooperation_rating   Wins  Initial_C_rate   CC_rate   CD_rate   DC_rate  \
# 0              0.499120  118.0        0.500422  0.250359  0.248762  0.251323
# 1              0.499498  118.0        0.513502  0.250848  0.248650  0.251306
# ...
